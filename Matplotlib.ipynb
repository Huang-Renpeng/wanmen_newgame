# %% [markdown]
# #  Matplotlib

# %%
import matplotlib

import  matplotlib.pyplot as plt
import numpy as np
import pandas as AApd
from IPython.display import Image
from IPython.display import *

# %matplotlib inline

# %% [markdown]
# # Installation

# %%
# This should be in the anacoda
# otherwise... https://matplotlib.org/users/installing.html

# %% [markdown]
# # Version

# %%
# 2.1.1 Latest stable version.
# 2.x Latest git master (unstable)
# 2.0.2 Previous stable version
# 1.5.3 Older stable version

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.0.3'

# %% [markdown]
# # Update

# %% [markdown]
# pip install --upgrade matplotlib

# %% [markdown]
# # simple plot

# %%
pd.set_option?

# %%
pd.set_option('display.mpl_style','default')  # FutureWarning: mpl_style had been deprecated and will be removed in a future version. 
# Use `matplotlib.pyplot.style.use` instead. exec(code_obj, self.user_global_ns, self.user_ns)

# plt.rcParams['figuare.figsize'] - (15,3)
# plt.rcParams['font.family'] = 'sans-serif'

weather_2012_final = pd.read_csv('weather_2012.csv',index_col='Date/Time')
weather_2012_final['Temp (C)'].plot(figsize=(15,6))
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-17-cda603c79c2f> in <module>
# ----> 1 pd.set_option('display.mpl_style','default')  # FutureWarning: mpl_style had been deprecated and will be removed in a future version.
#       2 # Use `matplotlib.pyplot.style.use` instead. exec(code_obj, self.user_global_ns, self.user_ns)
#       3
#       4 # plt.rcParams['figuare.figsize'] - (15,3)
#       5 # plt.rcParams['font.family'] = 'sans-serif'
#
# F:\Anaconda3\lib\site-packages\pandas\core\config.py in __call__(self, *args, **kwds)
#     225
#     226     def __call__(self, *args, **kwds):
# --> 227         return self.__func__(*args, **kwds)
#     228
#     229     @property
#
# F:\Anaconda3\lib\site-packages\pandas\core\config.py in _set_option(*args, **kwargs)
#     117
#     118     for k, v in zip(args[::2], args[1::2]):
# --> 119         key = _get_single_key(k, silent)
#     120
#     121         o = _get_registered_option(key)
#
# F:\Anaconda3\lib\site-packages\pandas\core\config.py in _get_single_key(pat, silent)
#      81         if not silent:
#      82             _warn_if_deprecated(pat)
# ---> 83         raise OptionError('No such keys(s): {pat!r}'.format(pat=pat))
#      84     if len(keys) > 1:
#      85         raise OptionError('Pattern matched multiple keys')
#
# OptionError: "No such keys(s): 'display.mpl_style'"

# %%
matplotlib.pyplot.style.use('default')
# plt.rcParams['figuare.figsize'] - (15,3)
# plt.rcParams['font.family'] = 'sans-serif'

weather_2012_final = pd.read_csv('weather_2012.csv',index_col='Date/Time')
weather_2012_final['Temp (C)'].plot(figsize=(15,6))

# %%
weather_2012_final.columns
# Out:
# Index(['Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)', 'Wind Spd (km/h)',
#        'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
print(weather_2012_final.shape)
weather_2012_final.head(5)
# Out:
# (8784, 7)
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# Date/Time
# 2012-01-01 00:00:00      -1.8                -3.9           86
# 2012-01-01 01:00:00      -1.8                -3.7           87
# 2012-01-01 02:00:00      -1.8                -3.4           89
# 2012-01-01 03:00:00      -1.5                -3.2           88
# 2012-01-01 04:00:00      -1.5                -3.3           88
#
#                      Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)  \
# Date/Time
# 2012-01-01 00:00:00                4              8.0           101.24
# 2012-01-01 01:00:00                4              8.0           101.24
# 2012-01-01 02:00:00                7              4.0           101.26
# 2012-01-01 03:00:00                6              4.0           101.27
# 2012-01-01 04:00:00                7              4.8           101.23
#
#                                   Weather
# Date/Time
# 2012-01-01 00:00:00                   Fog
# 2012-01-01 01:00:00                   Fog
# 2012-01-01 02:00:00  Freezing Drizzle,Fog
# 2012-01-01 03:00:00  Freezing Drizzle,Fog
# 2012-01-01 04:00:00                   Fog

# %%
weather_2012_final.describe()
# Out:
#           Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# count  8784.000000         8784.000000  8784.000000      8784.000000
# mean      8.798144            2.555294    67.431694        14.945469
# std      11.687883           10.883072    16.918881         8.688696
# min     -23.300000          -28.500000    18.000000         0.000000
# 25%       0.100000           -5.900000    56.000000         9.000000
# 50%       9.300000            3.300000    68.000000        13.000000
# 75%      18.800000           11.800000    81.000000        20.000000
# max      33.000000           24.400000   100.000000        83.000000
#
#        Visibility (km)  Stn Press (kPa)
# count      8784.000000      8784.000000
# mean         27.664447       101.051623
# std          12.622688         0.844005
# min           0.200000        97.520000
# 25%          24.100000       100.560000
# 50%          25.000000       101.070000
# 75%          25.000000       101.590000
# max          48.300000       103.650000

# %% [markdown]
# # Histogram

# %%
# Fixing random state for reproducibility
np.random.seed(2018)

mu,segma = 100,15
x = mu + segma * np.random.randn(10000)
# the histogram of the data
n,bins,patches = plt.hist(x,50,normed=1,facecolor='b',alpha=0.5)

print('n=',n)
print('bins=',bins)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40,160,0,0.03])
plt.grid(True)
plt.show()
# Out:
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# n= [4.08262010e-05 4.08262010e-05 4.08262010e-05 4.08262010e-05
#  8.16524021e-05 8.16524021e-05 1.63304804e-04 2.44957206e-04
#  4.08262010e-04 4.49088211e-04 9.39002624e-04 1.55139564e-03
#  2.16378865e-03 3.02113888e-03 3.55187949e-03 5.87897295e-03
#  6.77714937e-03 8.85928562e-03 1.20845555e-02 1.41666918e-02
#  1.44116490e-02 1.85759215e-02 2.16787127e-02 2.44957206e-02
#  2.51081136e-02 2.66595093e-02 2.63328997e-02 2.59654639e-02
#  2.61287687e-02 2.48631564e-02 2.24544106e-02 1.83717905e-02
#  1.56772612e-02 1.39625608e-02 1.17171197e-02 8.45102361e-03
#  6.65467077e-03 5.02162273e-03 3.30692228e-03 2.44957206e-03
#  1.46974324e-03 1.18395983e-03 1.02065503e-03 6.12393015e-04
#  4.89914412e-04 2.85783407e-04 1.63304804e-04 8.16524021e-05
#  4.08262010e-05 4.08262010e-05]
# bins= [ 35.26485539  37.71426282  40.16367025  42.61307767  45.0624851
#   47.51189253  49.96129995  52.41070738  54.86011481  57.30952223
#   59.75892966  62.20833709  64.65774451  67.10715194  69.55655937
#   72.0059668   74.45537422  76.90478165  79.35418908  81.8035965
#   84.25300393  86.70241136  89.15181878  91.60122621  94.05063364
#   96.50004106  98.94944849 101.39885592 103.84826334 106.29767077
#  108.7470782  111.19648562 113.64589305 116.09530048 118.5447079
#  120.99411533 123.44352276 125.89293018 128.34233761 130.79174504
#  133.24115246 135.69055989 138.13996732 140.58937474 143.03878217
#  145.4881896  147.93759702 150.38700445 152.83641188 155.2858193
#  157.73522673]

# %%
# the histogram of the data
n,bins,patches = plt.hist(weather_2012_final['Temp (C)'],5,facecolor='g',alpha=0.5)

print('n=',n)
print('bins=',bins)

plt.xlabel('Temperture in C')
plt.ylabel('Counts of days')
plt.title('Histogram of Temperture in year 2012')

plt.grid(True)
plt.show()
# Out:
# n= [ 295. 1728. 2578. 2788. 1395.]
# bins= [-23.3  -12.04  -0.78  10.48  21.74  33.  ]

# %% [markdown]
# # What is patches?

# %%
plt.plot?

# %%
plt.step?

# %%
x = np.random.normal(size=100)
#print(x)

n,bins,patches = plt.hist(x)
print(type(patches[0]))
plt.step(patches[0],'facecolor','r',alpha=0.5)
plt.show()
# Out:
# <class 'matplotlib.patches.Rectangle'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-144f1d72e8b8> in <module>
#       4 n,bins,patches = plt.hist(x)
#       5 print(type(patches[0]))
# ----> 6 plt.step(patches[0],'facecolor','r',alpha=0.5)
#       7 plt.show()
#
# F:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in step(x, y, where, data, *args, **kwargs)
#    2930     return gca().step(
#    2931         x, y, *args, where=where, **({"data": data} if data is not
# -> 2932         None else {}), **kwargs)
#    2933
#    2934
#
# F:\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in step(self, x, y, where, *args, **kwargs)
#    2062         kwargs['linestyle'] = 'steps-' + where + kwargs.get('linestyle', '')
#    2063
# -> 2064         return self.plot(x, y, *args, **kwargs)
#    2065
#    2066     @_preprocess_data(replace_names=["x", "left",
#
# F:\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1610
#    1611         for line in self._get_lines(*args, **kwargs):
# -> 1612             self.add_line(line)
#    1613             lines.append(line)
#    1614
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1893             line.set_clip_path(self.patch)
#    1894
# -> 1895         self._update_line_limits(line)
#    1896         if not line.get_label():
#    1897             line.set_label('_line%d' % len(self.lines))
#
# F:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1915         Figures out the data limit of the given line, updating self.dataLim.
#    1916         """
# -> 1917         path = line.get_path()
#    1918         if path.vertices.size == 0:
#    1919             return
#
# F:\Anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#     943         """
#     944         if self._invalidy or self._invalidx:
# --> 945             self.recache()
#     946         return self._path
#     947
#
# F:\Anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     638         if always or self._invalidx:
#     639             xconv = self.convert_xunits(self._xorig)
# --> 640             x = _to_unmasked_float_array(xconv).ravel()
#     641         else:
#     642             x = self._x
#
# F:\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1363         return np.ma.asarray(x, float).filled(np.nan)
#    1364     else:
# -> 1365         return np.asarray(x, float)
#    1366
#    1367
#
# F:\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# TypeError: float() argument must be a string or a number, not 'Rectangle'

# %% [markdown]
# # Scatter Plot

# %%
N =50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi *(15 * np.random.rand(N)) ** 2 # 0 to 15 point radii

# %%
np.random.rand?

# %%
# notice np.random.randn [-1,1]and half open np.random.rand [0,1)

# %%
# Show
plt.scatter(x,y,s=area,c=colors,alpha=0.5)
plt.show()

# %%
weather_2012_final.columns
# Out:
# Index(['Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)', 'Wind Spd (km/h)',
#        'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %%
# Show
N = weather_2012_final.shape[0]
colors = np.random.rand(N)
plt.scatter(weather_2012_final['Temp (C)'],weather_2012_final['Dew Point Temp (C)'],c=colors,alpha=0.5)
plt.xlabel('Temp (C)')
plt.ylabel('Dew Point Temp (C)')
plt.title('Histogram of Temperture in year 2012')
plt.show()

# %% [markdown]
# # Pie chart

# %%
labels = 'Cats','Birds','Dogs','Pandas'
sizes =[25,35,30,10]
explode =(0,0.08,0,0)

fig1,ax1 = plt.subplots()

plt.pie(sizes,explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)

ax1.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle
# Show
plt.show()

# %% [markdown]
# # About Sub-plots

# %%
import matplotlib

import  matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image
from IPython.display import *

# %matplotlib inline

# %%
# plot a line , implicitly creating a subplot(111)
plt.plot([1,2,3])
# now create a subplot which represents the top plot of a grid
# with 2 rows and 1 column. Since this subplot will overlap the
# first, the plot (and its axes) previously created, will removed
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212,facecolor='y')  # creates 2nd subplot with yellow background

# %%
plt.axes?

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# create some data to use for the plot
#*rect* = [left, bottom, width, height]

dt = 0.01
t = np.arange(0.0,10.0,dt)
r = np.exp(-t[:1000] / 0.05) # Impulse response
x = np.random.randn(len(t))
s = np.convolve(x,r)[:len(x)] * dt # colored default

# the main axes is subplot(111) by default
plt.plot(t,s)
plt.axis([0,1,1.1 * np.min(s),2 * np.max(s)])
plt.xlabel('time (s)')
plt.ylabel('current (nA)')
plt.title('Gaussian colored noise')

# this is an inset axes over the main axes
a = plt.axes([.65,.6,.2,.2],facecolor='k')
#n,bins,patches = plt.hist(s,40,normed=1)
n,bins,patches = plt.hist(s,40,density=1)
plt.title('Probability')
plt.xticks([])
plt.yticks([])
 
# this is another inset axes over the main axes
a = plt.axes([.2,.6,.2,.2],facecolor='k')
plt.plot(t[:len(r)],r)
plt.title('Impulse response')
plt.xlim(0,0.2)
plt.xticks([])
plt.yticks([])
 
plt.show()

# %%
#  gif referring from Brian Ambergderivative work:
#CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=11003835

with open('./Convolution_of_box_signal_with_itself2.gif','rb') as f:
    display(Image(data=f.read(),format='png'))

# %% [markdown]
# # Radar chart

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.path import Path
from matplotlib.spines import Spine
from matplotlib.projections.polar import PolarAxes
from matplotlib.projections import register_projection


def radar_factory(num_vars, frame='circle'):
    """Create a radar chart with `num_vars` axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle' | 'polygon'}
        Shape of frame surrounding axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    def draw_poly_patch(self):
        # rotate theta such that the first axis is at the top
        verts = unit_poly_verts(theta + np.pi / 2)
        return plt.Polygon(verts, closed=True, edgecolor='k')

    def draw_circle_patch(self):
        # unit circle centered on (0.5, 0.5)
        return plt.Circle((0.5, 0.5), 0.5)

    patch_dict = {'polygon': draw_poly_patch, 'circle': draw_circle_patch}
    if frame not in patch_dict:
        raise ValueError('unknown value for `frame`: %s' % frame)

    class RadarAxes(PolarAxes):

        name = 'radar'
        # use 1 line segment to connect specified points
        RESOLUTION = 1
        # define draw_frame method
        draw_patch = patch_dict[frame]

        def __init__(self, *args, **kwargs):
            super(RadarAxes, self).__init__(*args, **kwargs)
            # rotate plot such that the first axis is at the top
            self.set_theta_zero_location('N')

        def fill(self, *args, **kwargs):
            """Override fill so that line is closed by default"""
            closed = kwargs.pop('closed', True)
            return super(RadarAxes, self).fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            """Override plot so that line is closed by default"""
            lines = super(RadarAxes, self).plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.concatenate((x, [x[0]]))
                y = np.concatenate((y, [y[0]]))
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            return self.draw_patch()

        def _gen_axes_spines(self):
            if frame == 'circle':
                return PolarAxes._gen_axes_spines(self)
            # The following is a hack to get the spines (i.e. the axes frame)
            # to draw correctly for a polygon frame.

            # spine_type must be 'left', 'right', 'top', 'bottom', or `circle`.
            spine_type = 'circle'
            verts = unit_poly_verts(theta + np.pi / 2)
            # close off polygon by repeating first vertex
            verts.append(verts[0])
            path = Path(verts)

            spine = Spine(self, spine_type, path)
            spine.set_transform(self.transAxes)
            return {'polar': spine}

    register_projection(RadarAxes)
    return theta


def unit_poly_verts(theta):
    """Return vertices of polygon for subplot axes.

    This polygon is circumscribed by a unit circle centered at (0.5, 0.5)
    """
    x0, y0, r = [0.5] * 3
    verts = [(r*np.cos(t) + x0, r*np.sin(t) + y0) for t in theta]
    return verts


def example_data():
    # The following data is from the Denver Aerosol Sources and Health study.
    # See  doi:10.1016/j.atmosenv.2008.12.017
    #
    # The data are pollution source profile estimates for five modeled
    # pollution sources (e.g., cars, wood-burning, etc) that emit 7-9 chemical
    # species. The radar charts are experimented with here to see if we can
    # nicely visualize how the modeled source profiles change across four
    # scenarios:
    #  1) No gas-phase species present, just seven particulate counts on
    #     Sulfate
    #     Nitrate
    #     Elemental Carbon (EC)
    #     Organic Carbon fraction 1 (OC)
    #     Organic Carbon fraction 2 (OC2)
    #     Organic Carbon fraction 3 (OC3)
    #     Pyrolized Organic Carbon (OP)
    #  2)Inclusion of gas-phase specie carbon monoxide (CO)
    #  3)Inclusion of gas-phase specie ozone (O3).
    #  4)Inclusion of both gas-phase species is present...
    data = [
        ['Sulfate', 'Nitrate', 'EC', 'OC1', 'OC2', 'OC3', 'OP', 'CO', 'O3'],
        ('Basecase', [
            [0.88, 0.01, 0.03, 0.03, 0.00, 0.06, 0.01, 0.00, 0.00],
            [0.07, 0.95, 0.04, 0.05, 0.00, 0.02, 0.01, 0.00, 0.00],
            [0.01, 0.02, 0.85, 0.19, 0.05, 0.10, 0.00, 0.00, 0.00],
            [0.02, 0.01, 0.07, 0.01, 0.21, 0.12, 0.98, 0.00, 0.00],
            [0.01, 0.01, 0.02, 0.71, 0.74, 0.70, 0.00, 0.00, 0.00]]),
        ('With CO', [
            [0.88, 0.02, 0.02, 0.02, 0.00, 0.05, 0.00, 0.05, 0.00],
            [0.08, 0.94, 0.04, 0.02, 0.00, 0.01, 0.12, 0.04, 0.00],
            [0.01, 0.01, 0.79, 0.10, 0.00, 0.05, 0.00, 0.31, 0.00],
            [0.00, 0.02, 0.03, 0.38, 0.31, 0.31, 0.00, 0.59, 0.00],
            [0.02, 0.02, 0.11, 0.47, 0.69, 0.58, 0.88, 0.00, 0.00]]),
        ('With O3', [
            [0.89, 0.01, 0.07, 0.00, 0.00, 0.05, 0.00, 0.00, 0.03],
            [0.07, 0.95, 0.05, 0.04, 0.00, 0.02, 0.12, 0.00, 0.00],
            [0.01, 0.02, 0.86, 0.27, 0.16, 0.19, 0.00, 0.00, 0.00],
            [0.01, 0.03, 0.00, 0.32, 0.29, 0.27, 0.00, 0.00, 0.95],
            [0.02, 0.00, 0.03, 0.37, 0.56, 0.47, 0.87, 0.00, 0.00]]),
        ('CO & O3', [
            [0.87, 0.01, 0.08, 0.00, 0.00, 0.04, 0.00, 0.00, 0.01],
            [0.09, 0.95, 0.02, 0.03, 0.00, 0.01, 0.13, 0.06, 0.00],
            [0.01, 0.02, 0.71, 0.24, 0.13, 0.16, 0.00, 0.50, 0.00],
            [0.01, 0.03, 0.00, 0.28, 0.24, 0.23, 0.00, 0.44, 0.88],
            [0.02, 0.00, 0.18, 0.45, 0.64, 0.55, 0.86, 0.00, 0.16]])
    ]
    return data


if __name__ == '__main__':
    N = 9
    theta = radar_factory(N, frame='polygon')

    data = example_data()
    spoke_labels = data.pop(0)

    fig, axes = plt.subplots(figsize=(9, 9), nrows=2, ncols=2,
                             subplot_kw=dict(projection='radar'))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

    colors = ['b', 'r', 'g', 'm', 'y']
    # Plot the four cases from the example data on separate axes
    for ax, (title, case_data) in zip(axes.flatten(), data):
        ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
        ax.set_title(title, weight='bold', size='medium', position=(0.5, 1.1),
                     horizontalalignment='center', verticalalignment='center')
        for d, color in zip(case_data, colors):
            ax.plot(theta, d, color=color)
            ax.fill(theta, d, facecolor=color, alpha=0.25)
        ax.set_varlabels(spoke_labels)

    # add legend relative to top-left plot
    ax = axes[0, 0]
    labels = ('Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5')
    legend = ax.legend(labels, loc=(0.9, .95),
                       labelspacing=0.1, fontsize='small')

    fig.text(0.5, 0.965, '5-Factor Solution Profiles Across Four Scenarios',
             horizontalalignment='center', color='black', weight='bold',
             size='large')

    plt.show()

# %% [markdown]
# #  3D plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

X = np.arange(-5,5,0.25)
Y = np.arange(-5,5,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=cm.viridis)

plt.show()

# %% [markdown]
# # What about Math Function?

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0,2.0,0.01)
s = np.sin(2*np.pi*t)

plt.plot(t,s)
plt.title(r'$\alpha_i > \beta_i$',fontsize=20)
plt.text(1,-0.6,r'$\sum_{i=0}^ \infty x_i$',fontsize=20)
plt.text(0.6,0.6,r'$\mathcal{A} \mathcal{sin}(2 \omega t)$',fontsize=20)
plt.xlabel('time (s)')
plt.ylabel('volts (mV)')
plt.show()

# %% [markdown]
# * #  What about Images?

# %%
from scipy.misc import imread,imresize
import matplotlib.pyplot as plt
# %matplotlib inline

img = imread('./dog.jpg')
img_tinted = img * [1,1,0.95]
print(img.shape)

img_tinted = imresize(img_tinted,(500,600))

# Show the original image
plt.subplot(1,2,1)
plt.imshow(img)

# Show the tinted image
plt.subplot(1,2,2)
# A slight gotcha with  imshow is that it might give strange results
# if presented with data that is not uint8. To work around this. we
# explicitly cast the image to uint8 before displaying it.
plt.imshow(np.uint8(img_tinted))
plt.imshow()
# Out:
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """
# (168, 300, 3)
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-df63cdbea3f5> in <module>
#      19 # explicitly cast the image to uint8 before displaying it.
#      20 plt.imshow(np.uint8(img_tinted))
# ---> 21 plt.imshow()
#
# TypeError: imshow() missing 1 required positional argument: 'X'

# %%
print(img)
# Out:
# [[[ 72  69  36]
#   [ 71  68  35]
#   [ 70  67  34]
#   ...
#   [199 208 223]
#   [199 208 223]
#   [199 208 223]]
#
#  [[ 70  67  34]
#   [ 69  66  33]
#   [ 68  65  32]
#   ...
#   [198 207 222]
#   [198 207 222]
#   [198 207 222]]
#
#  [[ 68  65  32]
#   [ 67  64  31]
#   [ 65  62  29]
#   ...
#   [197 206 221]
#   [197 206 221]
#   [197 206 221]]
#
#  ...
#
#  [[148 147  55]
#   [147 146  54]
#   [146 145  53]
#   ...
#   [150 143  53]
#   [150 143  53]
#   [150 143  53]]
#
#  [[153 148  56]
#   [153 148  56]
#   [152 147  55]
#   ...
#   [156 149  59]
#   [156 149  59]
#   [156 149  59]]
#
#  [[153 146  55]
#   [153 146  55]
#   [152 145  54]
#   ...
#   [161 154  64]
#   [161 154  64]
#   [161 154  64]]]

# %% [markdown]
# #  Aggregation

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import  matplotlib
# %matplotlib inline
import  matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('dark')

# %% [markdown]
# # get a csv data set to play with
# url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/'

# %%
# Save thewinquality.csv file in the same folder as your ipython notebooks, note the delimiter used:
df_wine = pd.read_csv('winequality-red.csv',sep=';')

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# lets find out the average alcohol content for the winr
df_wine['alcohol'].mean()
# Out:
# 10.422983114446502

# %%
df_wine.quality.value_counts().plot(kind='bar')

# %% [markdown]
# * # Grounp by one key

# %%
# let's group the wines by 'quality'
wino = df_wine.groupby('quality')

# %%
wino_df=wino.mean()

# %%
wino_df.alcohol
# Out:
# quality
# 3     9.955000
# 4    10.265094
# 5     9.899706
# 6    10.629519
# 7    11.465913
# 8    12.094444
# Name: alcohol, dtype: float64

# %%
wino_df.pH.plot()

# %% [markdown]
# * # Grounp by two keys

# %%
df = pd.read_csv('train.csv')

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.Survived.groupby([df.Pclass,df.Sex]).mean()
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %%
mean = df.Survived.groupby([df.Pclass,df.Sex]).mean()

# %%
mean.unstack()
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
df.Survived.groupby([df.Pclass,df.Sex]).mean().plot.bar()

# %% [markdown]
# * # Not only stats but also size()

# %%
df.Survived.groupby([df.Pclass,df.Sex])

# %%
df.Survived.groupby([df.Pclass,df.Sex]).size()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: Survived, dtype: int64

# %% [markdown]
# * # how to interate?怎么遍历

# %%
for name,group in wino:
    print(name)
    print(group)
# Out:
# 3
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 459            11.6             0.580         0.66            2.20      0.074
# 517            10.4             0.610         0.49            2.10      0.200
# 690             7.4             1.185         0.00            4.25      0.097
# 832            10.4             0.440         0.42            1.50      0.145
# 899             8.3             1.020         0.02            3.40      0.084
# 1299            7.6             1.580         0.00            2.10      0.137
# 1374            6.8             0.815         0.00            1.20      0.267
# 1469            7.3             0.980         0.05            2.10      0.061
# 1478            7.1             0.875         0.05            5.70      0.082
# 1505            6.7             0.760         0.02            1.80      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 459                  10.0                  47.0  1.00080  3.25       0.57
# 517                   5.0                  16.0  0.99940  3.16       0.63
# 690                   5.0                  14.0  0.99660  3.63       0.54
# 832                  34.0                  48.0  0.99832  3.38       0.86
# 899                   6.0                  11.0  0.99892  3.48       0.49
# 1299                  5.0                   9.0  0.99476  3.50       0.40
# 1374                 16.0                  29.0  0.99471  3.32       0.51
# 1469                 20.0                  49.0  0.99705  3.31       0.55
# 1478                  3.0                  14.0  0.99808  3.40       0.52
# 1505                  6.0                  12.0  0.99600  3.55       0.63
#
#       alcohol  quality
# 459      9.00        3
# 517      8.40        3
# 690     10.70        3
# 832      9.90        3
# 899     11.00        3
# 1299    10.90        3
# 1374     9.80        3
# 1469     9.70        3
# 1478    10.20        3
# 1505     9.95        3
# 4
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 18              7.4             0.590         0.08             4.4      0.086
# 38              5.7             1.130         0.09             1.5      0.172
# 41              8.8             0.610         0.30             2.8      0.088
# 45              4.6             0.520         0.15             2.1      0.054
# 73              8.3             0.675         0.26             2.1      0.084
# 79              8.3             0.625         0.20             1.5      0.080
# 94              5.0             1.020         0.04             1.4      0.045
# 151             9.2             0.520         1.00             3.4      0.610
# 161             7.6             0.680         0.02             1.3      0.072
# 167             7.3             0.550         0.03             1.6      0.072
# 170             7.9             0.885         0.03             1.8      0.058
# 199             6.9             1.090         0.06             2.1      0.061
# 224             8.4             0.635         0.36             2.0      0.089
# 261             7.0             0.975         0.04             2.0      0.087
# 266             8.1             0.870         0.00             3.3      0.096
# 409            12.5             0.460         0.49             4.5      0.070
# 573            10.5             0.590         0.49             2.1      0.070
# 576             9.9             0.500         0.24             2.3      0.103
# 600             8.2             0.915         0.27             2.1      0.088
# 633            10.1             0.935         0.22             3.4      0.105
# 647             8.3             0.845         0.01             2.2      0.070
# 659             7.1             0.840         0.02             4.4      0.096
# 703             7.5             0.380         0.48             2.6      0.073
# 704             9.1             0.765         0.04             1.6      0.078
# 724             7.5             1.115         0.10             3.1      0.086
# 813             6.9             0.390         0.24             2.1      0.102
# 1189                  5.0                  19.0  0.99616  3.30       0.44
# 1233                 14.0                  36.0  0.99614  3.23       0.49
# 1235                  6.0                 113.0  0.99572  3.30       0.56
# 1238                 12.0                  24.0  0.99798  3.38       0.46
# 1239                 11.0                  20.0  0.99488  3.45       0.56
# 1261                 17.0                  24.0  0.99437  3.59       0.55
# 1263                 13.0                  26.0  0.99780  3.37       0.46
# 1276                  3.0                  10.0  0.99566  3.28       0.56
# 1293                  6.0                  12.0  0.99672  3.34       0.49
# 1307                 15.0                  29.0  0.99524  3.41       0.52
# 1363                 11.0                  63.0  0.99652  3.29       0.48
# 1369                  4.0                   8.0  0.99396  3.33       0.37
# 1423                 14.0                  31.0  0.99680  3.50       0.67
# 1461                  6.0                  13.0  0.99664  3.59       0.61
# 1467                 19.0                  32.0  0.99648  3.52       0.57
# 1480                  6.0                  13.0  0.99498  3.66       0.62
# 1482                  3.0                   9.0  0.99719  3.33       0.57
# 1484                  4.0                  11.0  0.99592  3.53       0.64
# 1521                  9.0                  23.0  0.99585  3.39       0.43
#
#       alcohol  quality
# 18       9.00        4
# 38       9.80        4
# 41       9.30        4
# 45      13.10        4
# 73       9.20        4
# 79       9.10        4
# 94      10.50        4
# 151      9.40        4
# 161      9.20        4
# 167      9.00        4
# 170      9.10        4
# 199     11.40        4
# 224     10.40        4
# 261      9.40        4
# 266      9.80        4
# 409      9.60        4
# 573      9.60        4
# 576     10.00        4
# 600     10.00        4
# 633     11.30        4
# 647     11.00        4
# 659     11.00        4
# 703      9.60        4
# 704      9.70        4
# 724     11.20        4
# 813     11.40        4
# 830     10.90        4
# 833      9.90        4
# 872     10.00        4
# 876     10.90        4
# 927      9.20        4
# 937     10.40        4
# 1124    11.50        4
# 1176    11.20        4
# 1189     9.60        4
# 1233     9.30        4
# 1235    11.50        4
# 1238     9.60        4
# 1239    11.80        4
# 1261    11.20        4
# 1263     9.60        4
# 1276    12.00        4
# 1293     9.70        4
# 1307    11.10        4
# 1363     9.80        4
# 1369    10.40        4
# 1423    11.00        4
# 1461    10.00        4
# 1467    11.00        4
# 1480    10.10        4
# 1482    10.30        4
# 1484    10.90        4
# 1521     9.05        4
# 5
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# 11              7.5             0.500         0.36             6.1      0.071
# 12              5.6             0.615         0.00             1.6      0.089
# 13              7.8             0.610         0.29             1.6      0.114
# 14              8.9             0.620         0.18             3.8      0.176
# 15              8.9             0.620         0.19             3.9      0.170
# 17              8.1             0.560         0.28             1.7      0.368
# 21              7.6             0.390         0.31             2.3      0.082
# 22              7.9             0.430         0.21             1.6      0.106
# 23              8.5             0.490         0.11             2.3      0.084
# 25              6.3             0.390         0.16             1.4      0.080
# 26              7.6             0.410         0.24             1.8      0.080
# 27              7.9             0.430         0.21             1.6      0.106
# 28              7.1             0.710         0.00             1.9      0.080
# 30              6.7             0.675         0.07             2.4      0.089
# 32              8.3             0.655         0.12             2.3      0.083
# 34              5.2             0.320         0.25             1.8      0.103
# 39              7.3             0.450         0.36             5.9      0.074
# 40              7.3             0.450         0.36             5.9      0.074
# 43              8.1             0.660         0.22             2.2      0.069
# 44              6.8             0.670         0.02             1.8      0.050
# 46              7.7             0.935         0.43             2.2      0.114
# 47              8.7             0.290         0.52             1.6      0.113
# ...             ...               ...          ...             ...        ...
# 1523            6.8             0.480         0.25             2.0      0.076
# 1525            6.7             0.480         0.08             2.1      0.064
# 1531            6.1             0.705         0.10             2.8      0.081
# 1533            8.0             0.390         0.30             1.9      0.074
# 1538            6.2             0.640         0.09             2.5      0.081
# 1539            7.2             0.390         0.32             1.8      0.065
# 1546            7.0             0.570         0.02             2.0      0.072
# 1547            6.3             0.600         0.10             1.6      0.048
# 1548           11.2             0.400         0.50             2.0      0.099
# 77                   14.0                  30.0  0.99660  3.52       0.55
# 84                   18.0                  61.0  0.99590  3.44       0.78
# 86                   20.0                 136.0  0.99720  2.93       1.95
# 91                   20.0                 136.0  0.99720  2.93       1.95
# 95                   17.0                 106.0  0.99320  3.85       0.60
# 99                   13.0                  35.0  0.99720  3.30       0.59
# 100                  11.0                  50.0  0.99720  3.40       0.61
# 101                   8.0                  22.0  0.99590  3.31       0.56
# 102                  13.0                  35.0  0.99720  3.30       0.59
# 108                  18.0                  80.0  0.99760  3.37       0.80
# 113                  22.0                  46.0  0.99880  3.32       0.67
# 115                  13.0                  62.0  0.99660  3.07       0.63
# 116                  11.0                  40.0  0.99780  3.39       0.61
# 117                   7.0                  28.0  0.99700  3.37       0.50
# ...                   ...                   ...      ...   ...        ...
# 1540                 11.0                  32.0  0.99646  3.56       0.63
# 1542                 29.0                  38.0  0.99472  3.30       0.56
# 1543                 14.0                  19.0  0.99758  3.25       0.57
# 1545                 16.0                  28.0  0.99531  3.36       0.64
# 1552                 32.0                  54.0  0.99586  3.51       0.66
# 1554                 15.0                  23.0  0.99627  3.54       0.60
# 1557                 15.0                  23.0  0.99627  3.54       0.60
# 1565                 26.0                  42.0  0.99489  3.39       0.82
# 1566                 24.0                  52.0  0.99494  3.34       0.71
# 1569                 15.0                  34.0  0.99396  3.48       0.57
# 1570                 19.0                  35.0  0.99340  3.37       0.93
# 1571                 15.0                  25.0  0.99514  3.44       0.65
# 1573                 15.0                  50.0  0.99467  3.58       0.67
# 1574                 23.0                  92.0  0.99677  3.39       0.48
# 1575                 12.0                  20.0  0.99474  3.26       0.64
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1577                 13.0                  27.0  0.99622  3.54       0.60
# 1578                 13.0                  20.0  0.99540  3.42       0.67
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1588                 34.0                 102.0  0.99414  3.27       0.78
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 3        9.80        6
# 19       9.20        6
# 20       9.40        6
# 24       9.70        6
# 29       9.80        6
# 31      10.60        6
# 33       9.40        6
# 35       9.60        6
# 36      10.80        6
# 42      10.50        6
# 51       9.40        6
# 52       9.40        6
# 54      10.20        6
# 59       9.40        6
# 69      10.50        6
# 70       9.50        6
# 77      10.70        6
# 84      10.30        6
# 86       9.90        6
# 91       9.90        6
# 95      12.90        6
# 99       9.00        6
# 100     10.20        6
# 101     10.40        6
# 102      9.00        6
# 108      9.60        6
# 113      9.70        6
# 115     10.50        6
# 116     10.00        6
# 117      9.40        6
# ...       ...      ...
# 1540    11.60        6
# 1542    10.75        6
# 1543    10.40        6
# 1545    10.10        6
# 1552    11.30        6
# 1554    11.00        6
# 1557    11.00        6
# 1565    10.90        6
# 1566    11.20        6
# 1569    11.50        6
# 1570    12.40        6
# 1571    11.10        6
# 1573    12.50        6
# 1574    10.50        6
# 1575    11.80        6
# 1576    10.80        6
# 1577    11.90        6
# 1578    11.30        6
# 1580    11.90        6
# 1585    11.50        6
# 1586    11.40        6
# 1587    10.90        6
# 1588    12.80        6
# 1590    11.60        6
# 1591    11.60        6
# 1592    11.00        6
# 1593     9.50        6
# 1595    11.20        6
# 1596    11.00        6
# 1598    11.00        6
#
# [638 rows x 12 columns]
# 7
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 16              8.5             0.280         0.56            1.80      0.092
# 37              8.1             0.380         0.28            2.10      0.066
# 62              7.5             0.520         0.16            1.90      0.085
# 128             8.0             0.590         0.16            1.80      0.065
# 198             5.4             0.835         0.08            1.20      0.046
# 200             9.6             0.320         0.47            1.40      0.056
# 205            12.8             0.300         0.74            2.60      0.095
# 206            12.8             0.300         0.74            2.60      0.095
# 209            11.0             0.300         0.58            2.10      0.054
# 230             5.2             0.480         0.04            1.60      0.054
# 1192  12.400000        7
# 1201  11.200000        7
# 1204  11.000000        7
# 1205  11.000000        7
# 1206  11.000000        7
# 1208  11.000000        7
# 1209  11.200000        7
# 1228  13.600000        7
# 1279  11.500000        7
# 1323  11.000000        7
# 1398  10.200000        7
# 1405  11.300000        7
# 1408  12.400000        7
# 1417  12.100000        7
# 1433  10.100000        7
# 1440  11.300000        7
# 1450  11.300000        7
# 1451  11.000000        7
# 1452  11.600000        7
# 1459  11.900000        7
# 1466  10.000000        7
# 1468  10.000000        7
# 1475  13.566667        7
# 1477  13.600000        7
# 1494  10.000000        7
# 1534  11.700000        7
# 1541  10.900000        7
# 1544  11.200000        7
# 1555  10.550000        7
# 1584  11.600000        7
#
# [199 rows x 12 columns]
# 8
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267             7.9              0.35         0.46             3.6      0.078
# 278            10.3              0.32         0.45             6.4      0.073
# 390             5.6              0.85         0.05             1.4      0.045
# 440            12.6              0.31         0.72             2.2      0.072
# 455            11.3              0.62         0.67             5.2      0.086
# 481             9.4              0.30         0.56             2.8      0.080
# 495            10.7              0.35         0.53             2.6      0.070
# 498            10.7              0.35         0.53             2.6      0.070
# 588             5.0              0.42         0.24             2.0      0.060
# 828             7.8              0.57         0.09             2.3      0.065
# 1061            9.1              0.40         0.50             1.8      0.071
# 1090           10.0              0.26         0.54             1.9      0.083
# 1120            7.9              0.54         0.34             2.5      0.076
# 1202            8.6              0.42         0.39             1.8      0.068
# 1269            5.5              0.49         0.03             1.8      0.044
# 1403            7.2              0.33         0.33             1.7      0.061
# 1449            7.2              0.38         0.31             2.0      0.056
# 1549            7.4              0.36         0.30             1.8      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 267                  15.0                  37.0  0.99730  3.35       0.86
# 278                   5.0                  13.0  0.99760  3.23       0.82
# 390                  12.0                  88.0  0.99240  3.56       0.82
# 440                   6.0                  29.0  0.99870  2.88       0.82
# 455                   6.0                  19.0  0.99880  3.22       0.69
# 481                   6.0                  17.0  0.99640  3.15       0.92
# 495                   5.0                  16.0  0.99720  3.15       0.65
# 498                   5.0                  16.0  0.99720  3.15       0.65
# 588                  19.0                  50.0  0.99170  3.72       0.74
# 828                  34.0                  45.0  0.99417  3.46       0.74
# 1061                  7.0                  16.0  0.99462  3.21       0.69
# 1090                 42.0                  74.0  0.99451  2.98       0.63
# 1120                  8.0                  17.0  0.99235  3.20       0.72
# 1202                  6.0                  12.0  0.99516  3.35       0.69
# 1269                 28.0                  87.0  0.99080  3.50       0.82
# 1403                  3.0                  13.0  0.99600  3.23       1.10
# 1449                 15.0                  29.0  0.99472  3.23       0.76
# 1549                 17.0                  24.0  0.99419  3.24       0.70
#
#       alcohol  quality
# 267      12.8        8
# 278      12.6        8
# 390      12.9        8
# 440       9.8        8
# 455      13.4        8
# 481      11.7        8
# 495      11.0        8
# 498      11.0        8
# 588      14.0        8
# 828      12.7        8
# 1061     12.5        8
# 1090     11.8        8
# 1120     13.1        8
# 1202     11.7        8
# 1269     14.0        8
# 1403     10.0        8
# 1449     11.3        8
# 1549     11.4        8

# %%
for (pclass,sex),group in df.Survived.groupby([df.Pclass,df.Sex]):
    print('pclass= ',pclass,'Sex=', sex)
# 831    1
# 841    0
# 848    0
# 861    0
# 864    0
# 883    0
# 886    0
# Name: Survived, Length: 108, dtype: int64
# pclass=  3 Sex= female
# group=
#  2      1
# 8      1
# 10     1
# 14     0
# 18     0
# 19     1
# 22     1
# 24     0
# 25     1
# 28     1
# 32     1
# 38     0
# 39     1
# 40     0
# 44     1
# 47     1
# 49     0
# 68     1
# 71     0
# 79     1
# 82     1
# 85     1
# 100    0
# 106    1
# 109    1
# 111    0
# 113    0
# 114    0
# 119    0
# 128    1
#       ..
# 657    0
# 677    1
# 678    0
# 680    0
# 691    1
# 697    1
# 702    0
# 727    1
# 729    0
# 736    0
# 767    0
# 777    1
# 780    1
# 786    1
# 792    0
# 797    1
# 799    0
# 807    0
# 813    0
# 816    0
# 823    1
# 830    1
# 852    0
# 855    1
# 858    1
# 863    0
# 875    1
# 882    0
# 885    0
# 888    0
# Name: Survived, Length: 144, dtype: int64
# pclass=  3 Sex= male
# group=
#  0      0
# 4      0
# 5      0
# 7      0
# 12     0
# 13     0
# 16     0
# 26     0
# 29     0
# 36     1
# 37     0
# 42     0
# 45     0
# 46     0
# 48     0
# 50     0
# 51     0
# 57     0
# 59     0
# 60     0
# 63     0
# 65     1
# 67     0
# 69     0
# 73     0
# 74     1
# 75     0
# 76     0
# 77     0
# 80     0
#       ..
# 824    0
# 825    0
# 826    0
# 828    1
# 832    0
# 833    0
# 834    0
# 836    0
# 837    0
# 838    1
# 840    0
# 843    0
# 844    0
# 845    0
# 846    0
# 847    0
# 850    0
# 851    0
# 859    0
# 860    0
# 868    0
# 869    1
# 870    0
# 873    0
# 876    0
# 877    0
# 878    0
# 881    0
# 884    0
# 890    0
# Name: Survived, Length: 347, dtype: int64

# %% [markdown]
# * # Group by from dict and sets

# %%
data = DataFrame(np.random.randn(5,5),columns=['apples','orange','cucumber','banana','patato'],
                 index = ['Monday','Tuesday','Wednesday','Thursday','Friday'])

# %%
data
# Out:
#              apples    orange  cucumber    banana    patato
# Monday    -1.813092 -0.253969  1.003101  0.530828  0.478870
# Tuesday   -0.738110 -1.181619 -0.531906 -1.215185 -0.795879
# Wednesday -0.189142 -0.584912 -0.904846 -0.993279 -0.495049
# Thursday   0.248997  0.028448 -1.747587  0.158027 -0.951449
# Friday     1.738592 -0.663905 -1.109423 -0.347243 -1.836321

# %%
goods ={'apples':'fruit','orange':'fruit','cucumber':'vegetable','banana':'fruit','potato':'vegetable'}

# %%
goods_by_date = data.groupby(goods,axis=1)

# %%
goods_by_date.sum()
# Out:
#               fruit  vegetable
# Monday    -1.536234   1.003101
# Tuesday   -3.134915  -0.531906
# Wednesday -1.767333  -0.904846
# Thursday   0.435472  -1.747587
# Friday     0.727444  -1.109423

# %%
# That was an example of an aggreate, how about we make aur own?
def range_values(arr):
    return arr.max() - arr.min()

# %%
# apply our own aggreate function, this function takes the max value of the col and subtracts the min value of the vol
wino.agg(range_values)
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                  4.9             1.140         0.66             4.5
# 4                  7.9             0.900         1.00            11.6
# 5                 10.9             1.150         0.79            14.3
# 6                  9.6             0.880         0.78            14.5
# 7                 10.7             0.795         0.76             7.7
# 8                  7.6             0.590         0.69             5.0
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.206                 31.0                  40.0  0.00609  0.47
# 4            0.565                 38.0                 112.0  0.00760  1.16
# 5            0.572                 65.0                 149.0  0.01059  0.86
# 6            0.381                 71.0                 159.0  0.01362  1.15
# 7            0.346                 51.0                 282.0  0.01256  0.86
# 8            0.042                 39.0                  76.0  0.00800  0.84
#
#          sulphates  alcohol
# quality
# 3             0.46      2.6
# 4             1.67      4.1
# 5             1.61      6.4
# 6             1.55      5.6
# 7             0.97      4.8
# 8             0.47      4.2

# %%
# We can also pass string methods through aggregate
wino.agg('sum')
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                 83.6             8.845         1.71           26.35
# 4                412.3            36.780         9.23          142.80
# 5               5561.9           392.965       165.95         1722.15
# 6               5325.5           317.395       174.70         1580.45
# 7               1765.6            80.380        74.66          541.40
# 8                154.2             7.620         7.04           46.40
#
#          chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# quality
# 3            1.225                110.0                 249.0    9.97464
# 4            4.806                650.0                1921.0   52.81675
# 5           63.153              11566.0               38486.0  679.02757
# 6           54.202              10024.0               26075.0  635.84041
# 7           15.241               2795.0                6969.0  198.22475
# 8            1.232                239.0                 602.0   17.91382
#
#               pH  sulphates      alcohol
# quality
# 3          33.98       5.70    99.550000
# 4         179.22      31.61   544.050000
# 5        2250.67     422.88  6741.700000
# 6        2116.93     430.86  6781.633333
# 7         654.86     147.51  2281.716667
# 8          58.81      13.82   217.700000

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# Let's adda quality to alcohol content ratio
df_wine['qual/alc ration'] = df_wine['quality']/df_wine['alcohol']

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  qual/alc ration
# 0      9.4        5         0.531915
# 1      9.8        5         0.510204
# 2      9.8        5         0.510204
# 3      9.8        6         0.612245
# 4      9.4        5         0.531915

# %%
# Use pivot table of quality instead of groupby
df_wine.pivot_table(index=['quality'])
# Out:
#            alcohol  chlorides  citric acid   density  fixed acidity  \
# quality
# 3         9.955000   0.122500     0.171000  0.997464       8.360000
# 4        10.265094   0.090679     0.174151  0.996542       7.779245
# 5         9.899706   0.092736     0.243686  0.997104       8.167254
# 6        10.629519   0.084956     0.273824  0.996615       8.347179
# 7        11.465913   0.076588     0.375176  0.996104       8.872362
# 8        12.094444   0.068444     0.391111  0.995212       8.566667
#
#          free sulfur dioxide        pH  qual/alc ration  residual sugar  \
# quality
# 3                  11.000000  3.398000         0.303286        2.635000
# 4                  12.264151  3.381509         0.392724        2.694340
# 5                  16.983847  3.304949         0.507573        2.528855
# 6                  15.711599  3.318072         0.569801        2.477194
# 7                  14.045226  3.290754         0.614855        2.720603
# 8                  13.277778  3.267222         0.668146        2.577778
#
#          sulphates  total sulfur dioxide  volatile acidity
# quality
# 3         0.570000             24.900000          0.884500
# 4         0.596415             36.245283          0.693962
# 5         0.620969             56.513950          0.577041
# 6         0.675329             40.869906          0.497484
# 7         0.741256             35.020101          0.403920
# 8         0.767778             33.444444          0.423333

# %%
# %matplotlib inline
df_wine.plot(kind='scatter',x='quality',y='alcohol')

# %% [markdown]
# # Practice

# %%
# %matplotlib inline
df_wine.groupby([df_wine.quality]).mean().alcohol.plot(kind='bar',y='alcohol')
